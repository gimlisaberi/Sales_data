# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\emers\\OneDrive\\Desktop\\sales.csv")
df.head()
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
# checking for duplicates! 

no_duplicate_df = df.drop_duplicates()
no_duplicate_df
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
# Unit price must be whole number, positive!

positive_unitprice = no_duplicate_df[no_duplicate_df['UnitPrice'] > 0]
positive_unitprice
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
#positive_unitprice['CustomerId'].isnull().value_counts()

cleaned_df = positive_unitprice.ffill()
cleaned_df
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
# report of top 5 customers with highest no of cancelings 

canceled_invoices = cleaned_df[cleaned_df['InvoiceNumber'].str.contains('C')]
canceled_invoices.head(5)
# Out:
#     InvoiceNumber ProductCode                    ProductName  Quantity  \
# 178       C489449       22087       PAPER BUNTING WHITE LACE       -12
# 179       C489449      85206A   CREAM FELT EASTER EGG BASKET        -6
# 180       C489449       21895  POTTING SHED SOW 'N' GROW SET        -4
# 181       C489449       21896             POTTING SHED TWINE        -6
# 182       C489449       22083     PAPER CHAIN KIT RETRO SPOT       -12
#
#              InvoiceDate  UnitPrice  CustomerId    Country
# 178  2009-12-01 10:33:00       2.95     16321.0  Australia
# 179  2009-12-01 10:33:00       1.65     16321.0  Australia
# 180  2009-12-01 10:33:00       4.25     16321.0  Australia
# 181  2009-12-01 10:33:00       2.10     16321.0  Australia
# 182  2009-12-01 10:33:00       2.95     16321.0  Australia

# %%
# removing canceled orders

final_cleaned_df = cleaned_df[~cleaned_df['InvoiceNumber'].str.contains('C')]
final_cleaned_df
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
# saving changes in remaining.csv

final_cleaned_df.to_csv('remaining.csv')

# %%
len(final_cleaned_df['InvoiceNumber'])
# Out:
# 504730

# %%
# min and max time range of ordering
min_invoice_data = final_cleaned_df['InvoiceDate'].min()
max_invoice_data = final_cleaned_df['InvoiceDate'].max()

print(min_invoice_data)
print(max_invoice_data)
# Out:
# 2009-12-01 07:45:00
# 2010-12-09 20:01:00

# %%
# Weekly Barplot of orders 

final_cleaned_df['InvoiceDate'] = pd.to_datetime(final_cleaned_df['InvoiceDate'])
final_cleaned_df['Day'] = final_cleaned_df['InvoiceDate'].dt.day_name()
product_day = final_cleaned_df.groupby('Day')['Quantity'].sum().reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_15548\4153972601.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_cleaned_df['InvoiceDate'] = pd.to_datetime(final_cleaned_df['InvoiceDate'])
# C:\Users\emers\AppData\Local\Temp\ipykernel_15548\4153972601.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_cleaned_df['Day'] = final_cleaned_df['InvoiceDate'].dt.day_name()

# %%
product_day.plot(kind = 'bar')
plt.xlabel = 'Day'
plt.ylabel = 'Products'
plt.title('Products in each day')
plt.figure(figsize=(8, 5))

# %%
#barplot showing total monthly sales per year

final_cleaned_df['Month'] = final_cleaned_df['InvoiceDate'].dt.month
final_cleaned_df['Year'] = final_cleaned_df['InvoiceDate'].dt.year
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_15548\297308351.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_cleaned_df['Month'] = final_cleaned_df['InvoiceDate'].dt.month
# C:\Users\emers\AppData\Local\Temp\ipykernel_15548\297308351.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_cleaned_df['Year'] = final_cleaned_df['InvoiceDate'].dt.year

# %%
final_cleaned_df['Sales'] = final_cleaned_df['Quantity'] * final_cleaned_df['UnitPrice']
sum_of_sales_per_month = final_cleaned_df.groupby(['Year','Month'])['Sales'].sum()
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_15548\4121508164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_cleaned_df['Sales'] = final_cleaned_df['Quantity'] * final_cleaned_df['UnitPrice']

# %%
plt.figure(figsize = (12,8))
sum_of_sales_per_month.plot(kind = 'bar')
plt.xlabel = 'Year & Month '
plt.ylabel = 'Sales'
plt.title('Sales per month')
# Out:
# Text(0.5, 1.0, 'Sales per month')
